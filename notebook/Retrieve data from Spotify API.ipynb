# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/0b/34/a01250ac1fc9bf9161e07956d2d580413106ce02d5591470130a25c599e3/redis-5.0.1-py3-none-any.whl.metadata
#   Downloading redis-5.0.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.11/site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /opt/conda/lib/python3.11/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from spotipy) (2.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2023.7.22)
# Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 6.3 MB/s eta 0:00:0000:01
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.1 spotipy-2.23.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Replace with your Spotify Developer App credentials
client_id = '0b97ee59b7114c80b1d8ea5616ca91a8'
client_secret = '868d26e716544c54b5092b8ef5c91254'

# Create a Spotify client with client credentials authentication
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# Replace with the URI or URL of the Spotify playlist you want to analyze
# playlist_uri = 'https://open.spotify.com/playlist/37i9dQZEVXbNcoJZ65xktI?si=3b46307eb84e4010'
playlist_uri = 'https://api.spotify.com/v1/search?type=track&q=isrc:USEE10001993'


# Get the playlist tracks
results = sp.search(playlist_uri)
# results = sp.playlist_tracks(playlist_uri)

tracks = results
print(tracks)
# tracks = results['items']
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=https%3A%2F%2Fapi.spotify.com%2Fv1%2Fsearch%3Ftype%3Dtrack%26q%3Disrc%3AUSEE10001993&type=track&offset=0&limit=10', 'items': [], 'limit': 10, 'next': None, 'offset': 0, 'previous': None, 'total': 0}}

# %%
moods = []

for track in tracks:
    # Extract the track ID
    track_id = track['track']['id']

    # Get audio features for the track
    audio_features = sp.audio_features(track_id)[0]
    print(audio_features)

    # Extract relevant mood-related features (e.g., valence, energy)
    valence = audio_features['valence']  # A measure of positivity/happiness
    energy = audio_features['energy']    # A measure of intensity/energy

    moods.append(valence)
    # # You can define your own criteria for moods based on these features
    # if valence > 0.6 and energy > 0.7:
    #     moods.append("Happy and Energetic")
    # elif valence > 0.6 and energy < 0.4:
    #     moods.append("Happy but Calm")
    # # Add more conditions for other moods

print("Moods in the playlist:")
for mood in moods:
    print(mood)
# Out:
# {'danceability': 0.868, 'energy': 0.538, 'key': 5, 'loudness': -8.603, 'mode': 1, 'speechiness': 0.174, 'acousticness': 0.269, 'instrumentalness': 3.34e-06, 'liveness': 0.0901, 'valence': 0.732, 'tempo': 99.968, 'type': 'audio_features', 'id': '2IGMVunIBsBLtEQyoI1Mu7', 'uri': 'spotify:track:2IGMVunIBsBLtEQyoI1Mu7', 'track_href': 'https://api.spotify.com/v1/tracks/2IGMVunIBsBLtEQyoI1Mu7', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IGMVunIBsBLtEQyoI1Mu7', 'duration_ms': 231750, 'time_signature': 4}
# {'danceability': 0.631, 'energy': 0.581, 'key': 10, 'loudness': -10.37, 'mode': 0, 'speechiness': 0.139, 'acousticness': 0.225, 'instrumentalness': 0.000495, 'liveness': 0.11, 'valence': 0.107, 'tempo': 94.998, 'type': 'audio_features', 'id': '4jiwxqE1yye4hzG5CpNcUH', 'uri': 'spotify:track:4jiwxqE1yye4hzG5CpNcUH', 'track_href': 'https://api.spotify.com/v1/tracks/4jiwxqE1yye4hzG5CpNcUH', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jiwxqE1yye4hzG5CpNcUH', 'duration_ms': 123789, 'time_signature': 4}
# {'danceability': 0.628, 'energy': 0.523, 'key': 11, 'loudness': -8.307, 'mode': 0, 'speechiness': 0.0946, 'acousticness': 0.701, 'instrumentalness': 0.00274, 'liveness': 0.219, 'valence': 0.416, 'tempo': 169.982, 'type': 'audio_features', 'id': '5mjYQaktjmjcMKcUIcqz4s', 'uri': 'spotify:track:5mjYQaktjmjcMKcUIcqz4s', 'track_href': 'https://api.spotify.com/v1/tracks/5mjYQaktjmjcMKcUIcqz4s', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mjYQaktjmjcMKcUIcqz4s', 'duration_ms': 172965, 'time_signature': 4}
# {'danceability': 0.527, 'energy': 0.861, 'key': 8, 'loudness': -6.73, 'mode': 1, 'speechiness': 0.0388, 'acousticness': 0.0155, 'instrumentalness': 0.0311, 'liveness': 0.276, 'valence': 0.387, 'tempo': 77.498, 'type': 'audio_features', 'id': '61BaxM1NIcadLu3gtWm2uT', 'uri': 'spotify:track:61BaxM1NIcadLu3gtWm2uT', 'track_href': 'https://api.spotify.com/v1/tracks/61BaxM1NIcadLu3gtWm2uT', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61BaxM1NIcadLu3gtWm2uT', 'duration_ms': 177346, 'time_signature': 4}
# {'danceability': 0.817, 'energy': 0.839, 'key': 0, 'loudness': -4.871, 'mode': 1, 'speechiness': 0.0635, 'acousticness': 0.0344, 'instrumentalness': 0, 'liveness': 0.1, 'valence': 0.452, 'tempo': 94.951, 'type': 'audio_features', 'id': '1E9hNjQeyecspfUZVmM4ZK', 'uri': 'spotify:track:1E9hNjQeyecspfUZVmM4ZK', 'track_href': 'https://api.spotify.com/v1/tracks/1E9hNjQeyecspfUZVmM4ZK', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1E9hNjQeyecspfUZVmM4ZK', 'duration_ms': 161684, 'time_signature': 4}
# {'danceability': 0.873, 'energy': 0.616, 'key': 0, 'loudness': -8.565, 'mode': 0, 'speechiness': 0.11, 'acousticness': 0.0487, 'instrumentalness': 0, 'liveness': 0.159, 'valence': 0.542, 'tempo': 130.13, 'type': 'audio_features', 'id': '7erP3ICSBISAa9ZH4vyo42', 'uri': 'spotify:track:7erP3ICSBISAa9ZH4vyo42', 'track_href': 'https://api.spotify.com/v1/tracks/7erP3ICSBISAa9ZH4vyo42', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7erP3ICSBISAa9ZH4vyo42', 'duration_ms': 199567, 'time_signature': 4}
# {'danceability': 0.726, 'energy': 0.873, 'key': 9, 'loudness': -3.122, 'mode': 1, 'speechiness': 0.0266, 'acousticness': 0.2, 'instrumentalness': 1.71e-06, 'liveness': 0.0953, 'valence': 0.725, 'tempo': 135.052, 'type': 'audio_features', 'id': '4kRLRWnn5u9wO2wOKAAdEN', 'uri': 'spotify:track:4kRLRWnn5u9wO2wOKAAdEN', 'track_href': 'https://api.spotify.com/v1/tracks/4kRLRWnn5u9wO2wOKAAdEN', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kRLRWnn5u9wO2wOKAAdEN', 'duration_ms': 129778, 'time_signature': 4}
# {'danceability': 0.802, 'energy': 0.832, 'key': 11, 'loudness': -4.107, 'mode': 1, 'speechiness': 0.0434, 'acousticness': 0.311, 'instrumentalness': 0, 'liveness': 0.0815, 'valence': 0.89, 'tempo': 124.997, 'type': 'audio_features', 'id': '7x9aauaA9cu6tyfpHnqDLo', 'uri': 'spotify:track:7x9aauaA9cu6tyfpHnqDLo', 'track_href': 'https://api.spotify.com/v1/tracks/7x9aauaA9cu6tyfpHnqDLo', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7x9aauaA9cu6tyfpHnqDLo', 'duration_ms': 185427, 'time_signature': 4}
# {'danceability': 0.747, 'energy': 0.711, 'key': 11, 'loudness': -5.448, 'mode': 0, 'speechiness': 0.0645, 'acousticness': 0.348, 'instrumentalness': 0, 'liveness': 0.311, 'valence': 0.766, 'tempo': 125.487, 'type': 'audio_features', 'id': '3gH5vuIvlmzHQkPGmbkXND', 'uri': 'spotify:track:3gH5vuIvlmzHQkPGmbkXND', 'track_href': 'https://api.spotify.com/v1/tracks/3gH5vuIvlmzHQkPGmbkXND', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gH5vuIvlmzHQkPGmbkXND', 'duration_ms': 159000, 'time_signature': 4}
# {'danceability': 0.72, 'energy': 0.674, 'key': 7, 'loudness': -7.344, 'mode': 0, 'speechiness': 0.0828, 'acousticness': 0.125, 'instrumentalness': 0.00258, 'liveness': 0.0928, 'valence': 0.219, 'tempo': 76.617, 'type': 'audio_features', 'id': '6gtK39SLszESqJFu2SkId3', 'uri': 'spotify:track:6gtK39SLszESqJFu2SkId3', 'track_href': 'https://api.spotify.com/v1/tracks/6gtK39SLszESqJFu2SkId3', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gtK39SLszESqJFu2SkId3', 'duration_ms': 92075, 'time_signature': 3}
# {'danceability': 0.761, 'energy': 0.793, 'key': 9, 'loudness': -4.578, 'mode': 0, 'speechiness': 0.0469, 'acousticness': 0.0908, 'instrumentalness': 6.68e-06, 'liveness': 0.566, 'valence': 0.548, 'tempo': 110.043, 'type': 'audio_features', 'id': '66Xj2OpnDALdW0G509b9yY', 'uri': 'spotify:track:66Xj2OpnDALdW0G509b9yY', 'track_href': 'https://api.spotify.com/v1/tracks/66Xj2OpnDALdW0G509b9yY', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/66Xj2OpnDALdW0G509b9yY', 'duration_ms': 176727, 'time_signature': 4}
# {'danceability': 0.691, 'energy': 0.68, 'key': 9, 'loudness': -6.478, 'mode': 0, 'speechiness': 0.0426, 'acousticness': 0.53, 'instrumentalness': 0, 'liveness': 0.102, 'valence': 0.546, 'tempo': 125.033, 'type': 'audio_features', 'id': '0vByMmR3Y8MBorEEE5Pmie', 'uri': 'spotify:track:0vByMmR3Y8MBorEEE5Pmie', 'track_href': 'https://api.spotify.com/v1/tracks/0vByMmR3Y8MBorEEE5Pmie', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vByMmR3Y8MBorEEE5Pmie', 'duration_ms': 149832, 'time_signature': 4}
# {'danceability': 0.658, 'energy': 0.822, 'key': 11, 'loudness': -6.425, 'mode': 0, 'speechiness': 0.142, 'acousticness': 0.1, 'instrumentalness': 1.88e-06, 'liveness': 0.213, 'valence': 0.531, 'tempo': 113.047, 'type': 'audio_features', 'id': '7Ce3VLSpVuwhWukkrumFA0', 'uri': 'spotify:track:7Ce3VLSpVuwhWukkrumFA0', 'track_href': 'https://api.spotify.com/v1/tracks/7Ce3VLSpVuwhWukkrumFA0', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Ce3VLSpVuwhWukkrumFA0', 'duration_ms': 225929, 'time_signature': 4}
# {'danceability': 0.508, 'energy': 0.43, 'key': 2, 'loudness': -9.475, 'mode': 0, 'speechiness': 0.0335, 'acousticness': 0.83, 'instrumentalness': 0.000441, 'liveness': 0.093, 'valence': 0.324, 'tempo': 130.09, 'type': 'audio_features', 'id': '1odExI7RdWc4BT515LTAwj', 'uri': 'spotify:track:1odExI7RdWc4BT515LTAwj', 'track_href': 'https://api.spotify.com/v1/tracks/1odExI7RdWc4BT515LTAwj', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1odExI7RdWc4BT515LTAwj', 'duration_ms': 212954, 'time_signature': 4}
# {'danceability': 0.593, 'energy': 0.641, 'key': 7, 'loudness': -12.727, 'mode': 0, 'speechiness': 0.0992, 'acousticness': 0.426, 'instrumentalness': 0.901, 'liveness': 0.122, 'valence': 0.147, 'tempo': 175.014, 'type': 'audio_features', 'id': '2ksyzVfU0WJoBpu8otr4pz', 'uri': 'spotify:track:2ksyzVfU0WJoBpu8otr4pz', 'track_href': 'https://api.spotify.com/v1/tracks/2ksyzVfU0WJoBpu8otr4pz', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ksyzVfU0WJoBpu8otr4pz', 'duration_ms': 142839, 'time_signature': 4}
# {'danceability': 0.877, 'energy': 0.803, 'key': 9, 'loudness': -3.195, 'mode': 1, 'speechiness': 0.0507, 'acousticness': 0.734, 'instrumentalness': 0.056, 'liveness': 0.087, 'valence': 0.795, 'tempo': 130.028, 'type': 'audio_features', 'id': '6njJR3OIp3oA0Kc4aC9Tzf', 'uri': 'spotify:track:6njJR3OIp3oA0Kc4aC9Tzf', 'track_href': 'https://api.spotify.com/v1/tracks/6njJR3OIp3oA0Kc4aC9Tzf', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6njJR3OIp3oA0Kc4aC9Tzf', 'duration_ms': 61673, 'time_signature': 4}
# {'danceability': 0.674, 'energy': 0.659, 'key': 8, 'loudness': -4.541, 'mode': 0, 'speechiness': 0.0338, 'acousticness': 0.259, 'instrumentalness': 0, 'liveness': 0.329, 'valence': 0.324, 'tempo': 150.075, 'type': 'audio_features', 'id': '34W2vfDZF6lOa4U55RsvDH', 'uri': 'spotify:track:34W2vfDZF6lOa4U55RsvDH', 'track_href': 'https://api.spotify.com/v1/tracks/34W2vfDZF6lOa4U55RsvDH', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34W2vfDZF6lOa4U55RsvDH', 'duration_ms': 239200, 'time_signature': 4}
# {'danceability': 0.863, 'energy': 0.62, 'key': 9, 'loudness': -6.766, 'mode': 0, 'speechiness': 0.0951, 'acousticness': 0.113, 'instrumentalness': 0, 'liveness': 0.357, 'valence': 0.81, 'tempo': 116.021, 'type': 'audio_features', 'id': '5FJssp1RN96K5AI7K2gJLY', 'uri': 'spotify:track:5FJssp1RN96K5AI7K2gJLY', 'track_href': 'https://api.spotify.com/v1/tracks/5FJssp1RN96K5AI7K2gJLY', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FJssp1RN96K5AI7K2gJLY', 'duration_ms': 140690, 'time_signature': 4}
# {'danceability': 0.654, 'energy': 0.743, 'key': 10, 'loudness': -7.19, 'mode': 0, 'speechiness': 0.0315, 'acousticness': 0.294, 'instrumentalness': 0.0495, 'liveness': 0.109, 'valence': 0.632, 'tempo': 169.98, 'type': 'audio_features', 'id': '4MQmxIxM5CXKjdq4IrCWhd', 'uri': 'spotify:track:4MQmxIxM5CXKjdq4IrCWhd', 'track_href': 'https://api.spotify.com/v1/tracks/4MQmxIxM5CXKjdq4IrCWhd', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MQmxIxM5CXKjdq4IrCWhd', 'duration_ms': 144236, 'time_signature': 4}
# {'danceability': 0.753, 'energy': 0.836, 'key': 6, 'loudness': -3.912, 'mode': 0, 'speechiness': 0.1, 'acousticness': 0.0403, 'instrumentalness': 0.000123, 'liveness': 0.0329, 'valence': 0.819, 'tempo': 99.969, 'type': 'audio_features', 'id': '6sVoLpo3i7p2WCaU3bpvpF', 'uri': 'spotify:track:6sVoLpo3i7p2WCaU3bpvpF', 'track_href': 'https://api.spotify.com/v1/tracks/6sVoLpo3i7p2WCaU3bpvpF', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6sVoLpo3i7p2WCaU3bpvpF', 'duration_ms': 131700, 'time_signature': 4}
# {'danceability': 0.73, 'energy': 0.785, 'key': 8, 'loudness': -6.512, 'mode': 1, 'speechiness': 0.0554, 'acousticness': 0.0464, 'instrumentalness': 0.0216, 'liveness': 0.111, 'valence': 0.649, 'tempo': 94.094, 'type': 'audio_features', 'id': '1N8TTK1Uoy7UvQNUazfUt5', 'uri': 'spotify:track:1N8TTK1Uoy7UvQNUazfUt5', 'track_href': 'https://api.spotify.com/v1/tracks/1N8TTK1Uoy7UvQNUazfUt5', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1N8TTK1Uoy7UvQNUazfUt5', 'duration_ms': 147875, 'time_signature': 4}
# {'danceability': 0.735, 'energy': 0.778, 'key': 11, 'loudness': -3.23, 'mode': 1, 'speechiness': 0.0487, 'acousticness': 0.00105, 'instrumentalness': 0.025, 'liveness': 0.0923, 'valence': 0.278, 'tempo': 126.091, 'type': 'audio_features', 'id': '4D1k6x4MXTaSnljSvAXhaf', 'uri': 'spotify:track:4D1k6x4MXTaSnljSvAXhaf', 'track_href': 'https://api.spotify.com/v1/tracks/4D1k6x4MXTaSnljSvAXhaf', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4D1k6x4MXTaSnljSvAXhaf', 'duration_ms': 127742, 'time_signature': 4}
# {'danceability': 0.711, 'energy': 0.6, 'key': 0, 'loudness': -10.639, 'mode': 1, 'speechiness': 0.141, 'acousticness': 0.419, 'instrumentalness': 1.33e-06, 'liveness': 0.0843, 'valence': 0.201, 'tempo': 112.126, 'type': 'audio_features', 'id': '7uHFrsclJjAhONLcc8grZU', 'uri': 'spotify:track:7uHFrsclJjAhONLcc8grZU', 'track_href': 'https://api.spotify.com/v1/tracks/7uHFrsclJjAhONLcc8grZU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uHFrsclJjAhONLcc8grZU', 'duration_ms': 168000, 'time_signature': 4}
# {'danceability': 0.613, 'energy': 0.81, 'key': 1, 'loudness': -6.16, 'mode': 1, 'speechiness': 0.488, 'acousticness': 0.832, 'instrumentalness': 0.899, 'liveness': 0.137, 'valence': 0.686, 'tempo': 150.251, 'type': 'audio_features', 'id': '0EqczV3o6fwksegAavIHpX', 'uri': 'spotify:track:0EqczV3o6fwksegAavIHpX', 'track_href': 'https://api.spotify.com/v1/tracks/0EqczV3o6fwksegAavIHpX', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EqczV3o6fwksegAavIHpX', 'duration_ms': 116104, 'time_signature': 4}
# {'danceability': 0.634, 'energy': 0.624, 'key': 9, 'loudness': -7.499, 'mode': 1, 'speechiness': 0.0709, 'acousticness': 0.0151, 'instrumentalness': 0, 'liveness': 0.115, 'valence': 0.546, 'tempo': 153.114, 'type': 'audio_features', 'id': '0Eseplnw5orGVSnaGNh3CH', 'uri': 'spotify:track:0Eseplnw5orGVSnaGNh3CH', 'track_href': 'https://api.spotify.com/v1/tracks/0Eseplnw5orGVSnaGNh3CH', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Eseplnw5orGVSnaGNh3CH', 'duration_ms': 160196, 'time_signature': 4}
# {'danceability': 0.869, 'energy': 0.456, 'key': 11, 'loudness': -8.533, 'mode': 0, 'speechiness': 0.497, 'acousticness': 0.681, 'instrumentalness': 0, 'liveness': 0.0698, 'valence': 0.381, 'tempo': 114.136, 'type': 'audio_features', 'id': '7krNeHssTmY3ijTox4OBbD', 'uri': 'spotify:track:7krNeHssTmY3ijTox4OBbD', 'track_href': 'https://api.spotify.com/v1/tracks/7krNeHssTmY3ijTox4OBbD', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7krNeHssTmY3ijTox4OBbD', 'duration_ms': 110526, 'time_signature': 4}
# {'danceability': 0.698, 'energy': 0.51, 'key': 5, 'loudness': -6.268, 'mode': 0, 'speechiness': 0.0423, 'acousticness': 0.464, 'instrumentalness': 0, 'liveness': 0.107, 'valence': 0.4, 'tempo': 129.979, 'type': 'audio_features', 'id': '0LydTnU3RQKbgMCKFWQ5nS', 'uri': 'spotify:track:0LydTnU3RQKbgMCKFWQ5nS', 'track_href': 'https://api.spotify.com/v1/tracks/0LydTnU3RQKbgMCKFWQ5nS', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LydTnU3RQKbgMCKFWQ5nS', 'duration_ms': 227560, 'time_signature': 4}
# {'danceability': 0.729, 'energy': 0.85, 'key': 1, 'loudness': -4.317, 'mode': 1, 'speechiness': 0.0586, 'acousticness': 0.101, 'instrumentalness': 1.62e-06, 'liveness': 0.0976, 'valence': 0.502, 'tempo': 119.997, 'type': 'audio_features', 'id': '3J5y9v6vK5ginTnMroJ1Nn', 'uri': 'spotify:track:3J5y9v6vK5ginTnMroJ1Nn', 'track_href': 'https://api.spotify.com/v1/tracks/3J5y9v6vK5ginTnMroJ1Nn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3J5y9v6vK5ginTnMroJ1Nn', 'duration_ms': 128016, 'time_signature': 4}
# {'danceability': 0.827, 'energy': 0.613, 'key': 1, 'loudness': -4.361, 'mode': 1, 'speechiness': 0.0484, 'acousticness': 0.196, 'instrumentalness': 0, 'liveness': 0.0891, 'valence': 0.634, 'tempo': 130.098, 'type': 'audio_features', 'id': '2YxL4H5c4NCPm19E28OPSt', 'uri': 'spotify:track:2YxL4H5c4NCPm19E28OPSt', 'track_href': 'https://api.spotify.com/v1/tracks/2YxL4H5c4NCPm19E28OPSt', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YxL4H5c4NCPm19E28OPSt', 'duration_ms': 157846, 'time_signature': 4}
# {'danceability': 0.769, 'energy': 0.31, 'key': 9, 'loudness': -14.249, 'mode': 0, 'speechiness': 0.372, 'acousticness': 0.872, 'instrumentalness': 0, 'liveness': 0.144, 'valence': 0.71, 'tempo': 77.994, 'type': 'audio_features', 'id': '6bCLkzoE3agC7Ws9NxVxIn', 'uri': 'spotify:track:6bCLkzoE3agC7Ws9NxVxIn', 'track_href': 'https://api.spotify.com/v1/tracks/6bCLkzoE3agC7Ws9NxVxIn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bCLkzoE3agC7Ws9NxVxIn', 'duration_ms': 120112, 'time_signature': 4}
# {'danceability': 0.588, 'energy': 0.593, 'key': 11, 'loudness': -7.975, 'mode': 0, 'speechiness': 0.0382, 'acousticness': 0.0897, 'instrumentalness': 0.000591, 'liveness': 0.112, 'valence': 0.263, 'tempo': 147.953, 'type': 'audio_features', 'id': '2R8CylfWLqBcejsXu2mdcW', 'uri': 'spotify:track:2R8CylfWLqBcejsXu2mdcW', 'track_href': 'https://api.spotify.com/v1/tracks/2R8CylfWLqBcejsXu2mdcW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2R8CylfWLqBcejsXu2mdcW', 'duration_ms': 147973, 'time_signature': 4}
# {'danceability': 0.826, 'energy': 0.4, 'key': 9, 'loudness': -12.597, 'mode': 0, 'speechiness': 0.316, 'acousticness': 0.439, 'instrumentalness': 0, 'liveness': 0.348, 'valence': 0.422, 'tempo': 120.047, 'type': 'audio_features', 'id': '4Yzlz45QgjUKZmN2KrK4AP', 'uri': 'spotify:track:4Yzlz45QgjUKZmN2KrK4AP', 'track_href': 'https://api.spotify.com/v1/tracks/4Yzlz45QgjUKZmN2KrK4AP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Yzlz45QgjUKZmN2KrK4AP', 'duration_ms': 148193, 'time_signature': 4}
# {'danceability': 0.793, 'energy': 0.707, 'key': 9, 'loudness': -4.367, 'mode': 0, 'speechiness': 0.12, 'acousticness': 0.328, 'instrumentalness': 0, 'liveness': 0.0872, 'valence': 0.561, 'tempo': 81.977, 'type': 'audio_features', 'id': '4QbAOvKJMIx22HvGqkFBmM', 'uri': 'spotify:track:4QbAOvKJMIx22HvGqkFBmM', 'track_href': 'https://api.spotify.com/v1/tracks/4QbAOvKJMIx22HvGqkFBmM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QbAOvKJMIx22HvGqkFBmM', 'duration_ms': 148537, 'time_signature': 4}
# {'danceability': 0.464, 'energy': 0.417, 'key': 0, 'loudness': -9.345, 'mode': 0, 'speechiness': 0.0256, 'acousticness': 0.136, 'instrumentalness': 0.022, 'liveness': 0.0974, 'valence': 0.479, 'tempo': 67.528, 'type': 'audio_features', 'id': '5XeFesFbtLpXzIVDNQP22n', 'uri': 'spotify:track:5XeFesFbtLpXzIVDNQP22n', 'track_href': 'https://api.spotify.com/v1/tracks/5XeFesFbtLpXzIVDNQP22n', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XeFesFbtLpXzIVDNQP22n', 'duration_ms': 183956, 'time_signature': 4}
# {'danceability': 0.79, 'energy': 0.979, 'key': 11, 'loudness': -4.637, 'mode': 0, 'speechiness': 0.117, 'acousticness': 0.0177, 'instrumentalness': 0.000192, 'liveness': 0.237, 'valence': 0.898, 'tempo': 161.014, 'type': 'audio_features', 'id': '6tAKikIvnoWfUeZrfkopLL', 'uri': 'spotify:track:6tAKikIvnoWfUeZrfkopLL', 'track_href': 'https://api.spotify.com/v1/tracks/6tAKikIvnoWfUeZrfkopLL', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tAKikIvnoWfUeZrfkopLL', 'duration_ms': 146087, 'time_signature': 4}
# {'danceability': 0.671, 'energy': 0.876, 'key': 7, 'loudness': -5.681, 'mode': 0, 'speechiness': 0.0352, 'acousticness': 0.12, 'instrumentalness': 0.188, 'liveness': 0.0823, 'valence': 0.964, 'tempo': 129.998, 'type': 'audio_features', 'id': '23RoR84KodL5HWvUTneQ1w', 'uri': 'spotify:track:23RoR84KodL5HWvUTneQ1w', 'track_href': 'https://api.spotify.com/v1/tracks/23RoR84KodL5HWvUTneQ1w', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23RoR84KodL5HWvUTneQ1w', 'duration_ms': 231545, 'time_signature': 4}
# {'danceability': 0.612, 'energy': 0.807, 'key': 10, 'loudness': -2.81, 'mode': 1, 'speechiness': 0.0336, 'acousticness': 0.0495, 'instrumentalness': 0.0177, 'liveness': 0.101, 'valence': 0.398, 'tempo': 124.053, 'type': 'audio_features', 'id': '2QjOHCTQ1Jl3zawyYOpxh6', 'uri': 'spotify:track:2QjOHCTQ1Jl3zawyYOpxh6', 'track_href': 'https://api.spotify.com/v1/tracks/2QjOHCTQ1Jl3zawyYOpxh6', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QjOHCTQ1Jl3zawyYOpxh6', 'duration_ms': 240400, 'time_signature': 4}
# {'danceability': 0.647, 'energy': 0.72, 'key': 2, 'loudness': -5.027, 'mode': 0, 'speechiness': 0.0482, 'acousticness': 0.469, 'instrumentalness': 1.93e-06, 'liveness': 0.068, 'valence': 0.241, 'tempo': 129.908, 'type': 'audio_features', 'id': '6ORlYPfvTXPZ4aHWVRp3Ey', 'uri': 'spotify:track:6ORlYPfvTXPZ4aHWVRp3Ey', 'track_href': 'https://api.spotify.com/v1/tracks/6ORlYPfvTXPZ4aHWVRp3Ey', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ORlYPfvTXPZ4aHWVRp3Ey', 'duration_ms': 201692, 'time_signature': 4}
# {'danceability': 0.712, 'energy': 0.972, 'key': 10, 'loudness': -0.514, 'mode': 1, 'speechiness': 0.112, 'acousticness': 0.00547, 'instrumentalness': 7.06e-05, 'liveness': 0.128, 'valence': 0.568, 'tempo': 119.966, 'type': 'audio_features', 'id': '6qyS9qBy0mEk3qYaH8mPss', 'uri': 'spotify:track:6qyS9qBy0mEk3qYaH8mPss', 'track_href': 'https://api.spotify.com/v1/tracks/6qyS9qBy0mEk3qYaH8mPss', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qyS9qBy0mEk3qYaH8mPss', 'duration_ms': 145000, 'time_signature': 4}
# {'danceability': 0.847, 'energy': 0.622, 'key': 1, 'loudness': -6.747, 'mode': 0, 'speechiness': 0.0903, 'acousticness': 0.119, 'instrumentalness': 0, 'liveness': 0.285, 'valence': 0.22, 'tempo': 130.001, 'type': 'audio_features', 'id': '4rXLjWdF2ZZpXCVTfWcshS', 'uri': 'spotify:track:4rXLjWdF2ZZpXCVTfWcshS', 'track_href': 'https://api.spotify.com/v1/tracks/4rXLjWdF2ZZpXCVTfWcshS', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rXLjWdF2ZZpXCVTfWcshS', 'duration_ms': 125040, 'time_signature': 4}
# {'danceability': 0.761, 'energy': 0.59, 'key': 10, 'loudness': -7.39, 'mode': 1, 'speechiness': 0.0339, 'acousticness': 0.171, 'instrumentalness': 0, 'liveness': 0.122, 'valence': 0.732, 'tempo': 113.997, 'type': 'audio_features', 'id': '28nCv762IfyLVB2OGGQcMb', 'uri': 'spotify:track:28nCv762IfyLVB2OGGQcMb', 'track_href': 'https://api.spotify.com/v1/tracks/28nCv762IfyLVB2OGGQcMb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28nCv762IfyLVB2OGGQcMb', 'duration_ms': 164211, 'time_signature': 4}
# {'danceability': 0.553, 'energy': 0.833, 'key': 7, 'loudness': -6.361, 'mode': 1, 'speechiness': 0.0394, 'acousticness': 0.0491, 'instrumentalness': 0.715, 'liveness': 0.121, 'valence': 0.662, 'tempo': 174.034, 'type': 'audio_features', 'id': '0wpkj8A7T1CjIul0XQtkqK', 'uri': 'spotify:track:0wpkj8A7T1CjIul0XQtkqK', 'track_href': 'https://api.spotify.com/v1/tracks/0wpkj8A7T1CjIul0XQtkqK', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wpkj8A7T1CjIul0XQtkqK', 'duration_ms': 150385, 'time_signature': 4}
# {'danceability': 0.65, 'energy': 0.477, 'key': 8, 'loudness': -5.944, 'mode': 1, 'speechiness': 0.144, 'acousticness': 0.207, 'instrumentalness': 0, 'liveness': 0.588, 'valence': 0.437, 'tempo': 135.419, 'type': 'audio_features', 'id': '0olubSy8HbZBrCJlSHV7ex', 'uri': 'spotify:track:0olubSy8HbZBrCJlSHV7ex', 'track_href': 'https://api.spotify.com/v1/tracks/0olubSy8HbZBrCJlSHV7ex', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0olubSy8HbZBrCJlSHV7ex', 'duration_ms': 144923, 'time_signature': 4}
# {'danceability': 0.691, 'energy': 0.631, 'key': 2, 'loudness': -6.478, 'mode': 1, 'speechiness': 0.0368, 'acousticness': 0.0483, 'instrumentalness': 1.13e-05, 'liveness': 0.104, 'valence': 0.8, 'tempo': 92.004, 'type': 'audio_features', 'id': '086myS9r57YsLbJpU0TgK9', 'uri': 'spotify:track:086myS9r57YsLbJpU0TgK9', 'track_href': 'https://api.spotify.com/v1/tracks/086myS9r57YsLbJpU0TgK9', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/086myS9r57YsLbJpU0TgK9', 'duration_ms': 161124, 'time_signature': 4}
# {'danceability': 0.294, 'energy': 0.603, 'key': 5, 'loudness': -5.711, 'mode': 0, 'speechiness': 0.0448, 'acousticness': 0.000764, 'instrumentalness': 0.93, 'liveness': 0.649, 'valence': 0.137, 'tempo': 158.022, 'type': 'audio_features', 'id': '6yt46G7lWn0oC2FEZZDsi6', 'uri': 'spotify:track:6yt46G7lWn0oC2FEZZDsi6', 'track_href': 'https://api.spotify.com/v1/tracks/6yt46G7lWn0oC2FEZZDsi6', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yt46G7lWn0oC2FEZZDsi6', 'duration_ms': 123333, 'time_signature': 4}
# {'danceability': 0.721, 'energy': 0.864, 'key': 1, 'loudness': -3.058, 'mode': 0, 'speechiness': 0.0676, 'acousticness': 0.0811, 'instrumentalness': 7.89e-05, 'liveness': 0.112, 'valence': 0.476, 'tempo': 106.0, 'type': 'audio_features', 'id': '7tHooYkoaE0myuzkPjyNHX', 'uri': 'spotify:track:7tHooYkoaE0myuzkPjyNHX', 'track_href': 'https://api.spotify.com/v1/tracks/7tHooYkoaE0myuzkPjyNHX', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tHooYkoaE0myuzkPjyNHX', 'duration_ms': 199387, 'time_signature': 4}
# {'danceability': 0.705, 'energy': 0.663, 'key': 9, 'loudness': -5.289, 'mode': 0, 'speechiness': 0.0367, 'acousticness': 0.18, 'instrumentalness': 6.74e-06, 'liveness': 0.0924, 'valence': 0.38, 'tempo': 124.988, 'type': 'audio_features', 'id': '3IhM5Mber8KA0NaRNpK2px', 'uri': 'spotify:track:3IhM5Mber8KA0NaRNpK2px', 'track_href': 'https://api.spotify.com/v1/tracks/3IhM5Mber8KA0NaRNpK2px', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3IhM5Mber8KA0NaRNpK2px', 'duration_ms': 140160, 'time_signature': 4}
# {'danceability': 0.67, 'energy': 0.867, 'key': 1, 'loudness': -3.436, 'mode': 0, 'speechiness': 0.0827, 'acousticness': 0.0829, 'instrumentalness': 0, 'liveness': 0.311, 'valence': 0.766, 'tempo': 96.952, 'type': 'audio_features', 'id': '4OX375hbVOIIYYOVKqGWKO', 'uri': 'spotify:track:4OX375hbVOIIYYOVKqGWKO', 'track_href': 'https://api.spotify.com/v1/tracks/4OX375hbVOIIYYOVKqGWKO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4OX375hbVOIIYYOVKqGWKO', 'duration_ms': 151000, 'time_signature': 4}
# {'danceability': 0.727, 'energy': 0.861, 'key': 4, 'loudness': -4.658, 'mode': 0, 'speechiness': 0.0908, 'acousticness': 0.00503, 'instrumentalness': 0.0019, 'liveness': 0.318, 'valence': 0.199, 'tempo': 102.531, 'type': 'audio_features', 'id': '4ststUuYxArgyAl3INmQUg', 'uri': 'spotify:track:4ststUuYxArgyAl3INmQUg', 'track_href': 'https://api.spotify.com/v1/tracks/4ststUuYxArgyAl3INmQUg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ststUuYxArgyAl3INmQUg', 'duration_ms': 120585, 'time_signature': 4}
# {'danceability': 0.861, 'energy': 0.485, 'key': 4, 'loudness': -8.61, 'mode': 1, 'speechiness': 0.128, 'acousticness': 0.742, 'instrumentalness': 2.63e-06, 'liveness': 0.0848, 'valence': 0.562, 'tempo': 108.129, 'type': 'audio_features', 'id': '2oUSzRUIE4GvMw29rLKlWw', 'uri': 'spotify:track:2oUSzRUIE4GvMw29rLKlWw', 'track_href': 'https://api.spotify.com/v1/tracks/2oUSzRUIE4GvMw29rLKlWw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2oUSzRUIE4GvMw29rLKlWw', 'duration_ms': 135346, 'time_signature': 4}
# Moods in the playlist:
# 0.732
# 0.107
# 0.416
# 0.387
# 0.452
# 0.542
# 0.725
# 0.89
# 0.766
# 0.219
# 0.548
# 0.546
# 0.531
# 0.324
# 0.147
# 0.795
# 0.324
# 0.81
# 0.632
# 0.819
# 0.649
# 0.278
# 0.201
# 0.686
# 0.546
# 0.381
# 0.4
# 0.502
# 0.634
# 0.71
# 0.263
# 0.422
# 0.561
# 0.479
# 0.898
# 0.964
# 0.398
# 0.241
# 0.568
# 0.22
# 0.732
# 0.662
# 0.437
# 0.8
# 0.137
# 0.476
# 0.38
# 0.766
# 0.199
# 0.562
