# %%
# !pip install requests
# !pip install bs4
# !pip install pandas
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: bs4 in /opt/conda/lib/python3.11/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def allsundays(year):
    return pd.date_range(start=str(year), end=str(year+1), 
                         freq='W-FRI').strftime('%Y-%m-%d').tolist()

weeks = allsundays(2023)[:39]  # First 5 Sundays of 2017

for week in weeks:
    scrapeData(week)
# Out:
# ['2023-01-07', '2023-01-14', '2023-01-21', '2023-01-28', '2023-02-04', '2023-02-11', '2023-02-18', '2023-02-25', '2023-03-04', '2023-03-11', '2023-03-18', '2023-03-25', '2023-04-01', '2023-04-08', '2023-04-15', '2023-04-22', '2023-04-29', '2023-05-06', '2023-05-13', '2023-05-20', '2023-05-27', '2023-06-03', '2023-06-10', '2023-06-17', '2023-06-24', '2023-07-01', '2023-07-08', '2023-07-15', '2023-07-22', '2023-07-29', '2023-08-05', '2023-08-12', '2023-08-19', '2023-08-26', '2023-09-02', '2023-09-09', '2023-09-16', '2023-09-23', '2023-09-30']
# <Response [500]>
# <Response [500]>
# <Response [500]>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 13
#      10 print(weeks)
#      12 for week in weeks:
# ---> 13     scrapeData(week)
#
# Cell In[54], line 14, in scrapeData(week)
#      12 def scrapeData(week):
#      13     # Making a GET request
# ---> 14     r = requests.get('https://tophit.com/chart/top/media/hits/ukraine/weekly/' + week)
#      15     print(r)
#      17     # Parsing the HTML
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/conda/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/conda/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/conda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def allsundays(year):
    return pd.date_range(start=str(year), end=str(year+1), 
                         freq='W-FRI').strftime('%Y-%m-%d').tolist()

weeks = allsundays(2023)[:39]  # First 5 Sundays of 2017

def scrapeData(week):
    # Making a GET request
    r = requests.get('https://tophit.com/chart/top/media/hits/ukraine/weekly/' + week)
    print(r)
     
    # Parsing the HTML
    soup = BeautifulSoup(r.content, 'html.parser')
    
    # Locate the element containing the song rows
    song_rows = soup.find_all('div', class_='Row_name__vEYs2')
    
    # Extract and print the song data
    for song in song_rows:
        song_name = song.find('div', class_='flex items-center gap-x-1.5').text.strip()
        artist_name = song.find('div', class_='truncate pb-0.5 text-sm leading-4 text-gray-500').text.strip()
        
        print(f"Song: {song_name}\nArtist: {artist_name}\n")

for week in weeks:
    scrapeData(week)
    time.sleep(5)
# Out:
# <Response [200]>
# Song: Hear The Anthem
# Artist: Skofka
#
# Song: There By The Poplar Tree
# Artist: Artem Pivovarov & NK
#
# Song: Whatever Happens
# Artist: Dorofeeva
#
# Song: For The Money Yes
# Artist: Instasamka
#
# Song: Stefania
# Artist: Kalush Orchestra
#
# Song: Conducted An Excursion
# Artist: Parfeniuk
#
# Song: That's Good
# Artist: Cheev
#
# Song: Monro
# Artist: Slavik Pogosov
#
# Song: Motherland
# Artist: Kalush & Skofka
#
# Song: Thoughts
# Artist: Artem Pivovarov & Dorofeeva
#
# Song: Swallows
# Artist: Chico & Qatoshi
#
# Song: Near The Poplar
# Artist: Shumei
#
# Song: Near The Heart
# Artist: Kola
#
# Song: Vespers (Good Day Everybody)
# Artist: 100lycya & Skylerr
#
# Song: Go Home
# Artist: Wellboy
#
# Song: Waiting At Home
# Artist: Yaktak feat. Dovi
#
# Song: You'll Be Happy (Grove, Green Grove)
# Artist: Dima Prokopov
#
# Song: Bloody Mary
# Artist: Lady Gaga
#
# Song: Wild Field
# Artist: Yarmak feat. Alisa
#
# Song: What A Cossack You Are
# Artist: Anna Trincher & Positiff
#
# Song: Oh, On The Mountain
# Artist: Artem Pivovarov
#
# Song: Vanka Standing Up
# Artist: Masha Kondratenko
#
# Song: Wont Forget You
# Artist: Shouse
#
# Song: How Long
# Artist: Tove Lo
#
# Song: Middle Of The Night
# Artist: Elley Duhe
#
# Song: I'm Good (Blue)
# Artist: David Guetta & Bebe Rexha
#
# Song: In The Shadows Of Ukraine
# Artist: Kalush Orchestra feat. The Rasmus
#
# Song: Shot A Friend
# Artist: Holy Molly
#
# Song: Not About Us
# Artist: Alis Shuka
#
# Song: In The Dark
# Artist: Purple Disco Machine & Sophie And The Giants
#
# Song: Ukraine Will Win
# Artist: Oleksandr Ponomaryov & Mykhaylo Khoma & Taras Topolia & Yevhen Koshovyi & Yuriy Tkach & Petro Chornyy
#
# Song: Crystal
# Artist: NK
#
# Song: My Country
# Artist: Yarmak feat. Tof
#
# Song: Enemy (Radio Edit)
# Artist: Angy Kreyda
#
# Song: At The Bars
# Artist: Anna Asti
#
# Song: Unbreakable
# Artist: Lyusya Kava
#
# Song: We'll Not Forget And We'll Not Forgive
# Artist: Skofka
#
# Song: Bunny
# Artist: Anna Trincher
#
# Song: How Mommy
# Artist: Instasamka
#
# Song: Where
# Artist: Ivan Navi
#
# Song: Silhouettes
# Artist: SadSvit & Struktura Shastya
#
# Song: Unholy
# Artist: Sam Smith feat. Kim Petras
#
# Song: As It Was
# Artist: Harry Styles
#
# Song: Enemy
# Artist: Angy Kreyda
#
# Song: The AFU Will Help
# Artist: Chico & Qatoshi
#
# Song: Sigele-Migele
# Artist: Nazva
#
# Song: My Ukraine
# Artist: TamerlanAlena & Andi Vax
#
# Song: Warriors Of Light
# Artist: Lyapis Trubetskoy
#
# Song: Mmm
# Artist: Minelli
#
# Song: Oh, Red Viburnum In The Meadow (Army Remix)
# Artist: The Kiffness feat. Boomboks
#
# Song: View
# Artist: Yaktak feat. Sobol'
#
# Song: You Dream
# Artist: Cheev
#
# Song: Style
# Artist: Wellboy
#
# Song: Metamorphosis
# Artist: Interworld
#
# Song: When The War Ends
# Artist: Yuliya Dumansʹka
#
# Song: Good Evening (Where Are You From?)
# Artist: Probass ∆ Hardi
#
# Song: Yin Yan (OST Neighbor)
# Artist: Monatik & Roxolana
#
# Song: Marichka
# Artist: Patsyki Z Franeka
#
# Song: You're So Beautiful
# Artist: Quest Pistols
#
# Song: My Country
# Artist: Arsen Mirzoyan
#
# Song: Dog Patron
# Artist: Karta Svitu
#
# Song: Live
# Artist: Yuliya Roznen
#
# Song: Enemies On Knives
# Artist: Wellboy
#
# Song: I'm Writing You A Letter
# Artist: Ivan Navi
#
# Song: Flowers Of Mine Zones
# Artist: Okean El`zy
#
# Song: This Dream
# Artist: Lesya Nikityuk & Stepan Hiha
#
# Song: Polar Star
# Artist: Mosovich & Batrai
#
# Song: Carol, Ukraine!
# Artist: Roman Skorpion & Yuriana
#
# Song: My Little Hooligan
# Artist: Xolidayboy
#
# Song: To The Occupier
# Artist: MBreeze
#
# Song: Thought She Was An Angel
# Artist: Kolin
#
# Song: Another Love
# Artist: Tom Odell
#
# Song: Heart Of Steel
# Artist: Tvorchi
#
# Song: Or Together?
# Artist: Kola
#
# Song: Where Did You Go?
# Artist: Jax Jones feat. MNEK
#
# Song: All I Want For Christmas Is You
# Artist: Mariah Carey
#
# Song: Manifesto (Radio Edit)
# Artist: Artem Pivovarov
#
# Song: Black & White
# Artist: Zozulya
#
# Song: Walking
# Artist: Kozak Siromaha
#
# Song: Good Afternoon Everybody
# Artist: Myusli UA feat. Vasia Charizma
#
# Song: The Motto
# Artist: Tiesto & Ava Max
#
# Song: Bell
# Artist: Skylerr & Sanaria
#
# Song: Haj Іsus male ditya
# Artist: Iryna Fedyshyn
#
# Song: On The Road
# Artist: Skofka
#
# Song: Ukraina Kolyadue
# Artist: Iryna Fedyshyn
#
# Song: Spit On My Face!
# Artist: ThxSoMch
#
# Song: Leave Before You Love Me
# Artist: Marshmello & Jonas Brothers
#
# Song: My Only Wish (This Year)
# Artist: Britney Spears
#
# Song: I'm A Soldier (2022 UA Version)
# Artist: Serhii Babkin
#
# Song: Mockingbird
# Artist: Eminem
#
# Song: Saint Javelin
# Artist: TaRuta
#
# Song: Our Father Bandera
# Artist: Glova & Manin & Govorun
#
# Song: 2step
# Artist: Ed Sheeran feat. Antytila
#
# Song: The Magic Eyes
# Artist: Olya Polyakova
#
# Song: U Mene Nemaye Domu
# Artist: Odyn v kanoe
#
# Song: Russian, Come On, Run Faster
# Artist: Bakun & Varash
#
# Song: Rampampam
# Artist: Minelli
#
# Song: Your Love (9pm)
# Artist: ATB & Topic & A7S
#
# Song: Viburnum Cried
# Artist: Polina Dashkova
#
# Song: Ukrainian Rage (Bella Ciao cover)
# Artist: Khrystyna Soloviy
#
# <Response [200]>
# Song: Hear The Anthem
# Artist: Skofka
#
# Song: There By The Poplar Tree
# Artist: Artem Pivovarov & NK
#
# Song: Whatever Happens
# Artist: Dorofeeva
#
# Song: Flowers
# Artist: Miley Cyrus
#
# Song: Stefania
# Artist: Kalush Orchestra
#
# Song: That's Good
# Artist: Cheev
#
# Song: Conducted An Excursion
# Artist: Parfeniuk
#
# Song: For The Money Yes
# Artist: Instasamka
#
# Song: Motherland
# Artist: Kalush & Skofka
#
# Song: Near The Heart
# Artist: Kola
#
# Song: Thoughts
# Artist: Artem Pivovarov & Dorofeeva
#
# Song: Near The Poplar
# Artist: Shumei
#
# Song: Swallows
# Artist: Chico & Qatoshi
#
# Song: Waiting At Home
# Artist: Yaktak feat. Dovi
#
# Song: Monro
# Artist: Slavik Pogosov
#
# Song: Go Home
# Artist: Wellboy
#
# Song: Vespers (Good Day Everybody)
# Artist: 100lycya & Skylerr
#
# Song: Wont Forget You
# Artist: Shouse
#
# Song: Not About Us
# Artist: Alis Shuka
#
# Song: Middle Of The Night
# Artist: Elley Duhe
#
# Song: You'll Be Happy (Grove, Green Grove)
# Artist: Dima Prokopov
#
# Song: What A Cossack You Are
# Artist: Anna Trincher & Positiff
#
# Song: How Long
# Artist: Tove Lo
#
# Song: Shot A Friend
# Artist: Holy Molly
#
# Song: Oh, On The Mountain
# Artist: Artem Pivovarov
#
# Song: Sigele-Migele
# Artist: Nazva
#
# Song: Enemy
# Artist: Angy Kreyda
#
# Song: Wild Field
# Artist: Yarmak feat. Alisa
#
# Song: Bunny
# Artist: Anna Trincher
#
# Song: In The Shadows Of Ukraine
# Artist: Kalush Orchestra feat. The Rasmus
#
# Song: I'm Good (Blue)
# Artist: David Guetta & Bebe Rexha
#
# Song: Vanka Standing Up
# Artist: Masha Kondratenko
#
# Song: In The Dark
# Artist: Purple Disco Machine & Sophie And The Giants
#
# Song: Good Afternoon Everybody
# Artist: Myusli UA feat. Vasia Charizma
#
# Song: Manifesto (Radio Edit)
# Artist: Artem Pivovarov
#
# Song: My Country
# Artist: Yarmak feat. Tof
#
# Song: We'll Not Forget And We'll Not Forgive
# Artist: Skofka
#
# Song: Bloody Mary
# Artist: Lady Gaga
#
# Song: U Mene Nemaye Domu
# Artist: Odyn v kanoe
#
# Song: Unbreakable
# Artist: Lyusya Kava
#
# Song: Ukraine Will Win
# Artist: Oleksandr Ponomaryov & Mykhaylo Khoma & Taras Topolia & Yevhen Koshovyi & Yuriy Tkach & Petro Chornyy
#
# Song: Enemy (Radio Edit)
# Artist: Angy Kreyda
#
# Song: Silhouettes
# Artist: SadSvit & Struktura Shastya
#
# Song: Unholy
# Artist: Sam Smith feat. Kim Petras
#
# Song: Where
# Artist: Ivan Navi
#
# Song: Mmm
# Artist: Minelli
#
# Song: How Mommy
# Artist: Instasamka
#
# Song: As It Was
# Artist: Harry Styles
#
# Song: View
# Artist: Yaktak feat. Sobol'
#
# Song: At The Bars
# Artist: Anna Asti
#
# Song: The AFU Will Help
# Artist: Chico & Qatoshi
#
# Song: Warriors Of Light
# Artist: Lyapis Trubetskoy
#
# Song: My Country
# Artist: Arsen Mirzoyan
#
# Song: This Dream
# Artist: Lesya Nikityuk & Stepan Hiha
#
# Song: You're So Beautiful
# Artist: Quest Pistols
#
# Song: Marichka
# Artist: Patsyki Z Franeka
#
# Song: Metamorphosis
# Artist: Interworld
#
# Song: Oh, Red Viburnum In The Meadow (Army Remix)
# Artist: The Kiffness feat. Boomboks
#
# Song: You Dream
# Artist: Cheev
#
# Song: Dog Patron
# Artist: Karta Svitu
#
# Song: I'm Writing You A Letter
# Artist: Ivan Navi
#
# Song: Crystal
# Artist: NK
#
# Song: The Motto
# Artist: Tiesto & Ava Max
#
# Song: Good Evening (Where Are You From?)
# Artist: Probass ∆ Hardi
#
# Song: Style
# Artist: Wellboy
#
# Song: My Ukraine
# Artist: TamerlanAlena & Andi Vax
#
# Song: Walking
# Artist: Kozak Siromaha
#
# Song: Or Together?
# Artist: Kola
#
# Song: Cold Heart (Pnau Remix)
# Artist: Elton John & Dua Lipa & Pnau
#
# Song: I'm A Soldier (2022 UA Version)
# Artist: Serhii Babkin
#
# Song: Bell
# Artist: Skylerr & Sanaria
#
# Song: Ukrainian Rage (Bella Ciao cover)
# Artist: Khrystyna Soloviy
#
# Song: To The Occupier
# Artist: MBreeze
#
# Song: Cossack Genus
# Artist: Jerry Heil
#
# Song: Thought She Was An Angel
# Artist: Kolin
#
# Song: Yin Yan (OST Neighbor)
# Artist: Monatik & Roxolana
#
# Song: Black & White
# Artist: Zozulya
#
# Song: Live
# Artist: Yuliya Roznen
#
# Song: My Little Hooligan
# Artist: Xolidayboy
#
# Song: 2step
# Artist: Ed Sheeran feat. Antytila
#
# Song: Mockingbird
# Artist: Eminem
#
# Song: Flowers Of Mine Zones
# Artist: Okean El`zy
#
# Song: Polar Star
# Artist: Mosovich & Batrai
#
# Song: On The Road
# Artist: Skofka
#
# Song: Take You Dancing
# Artist: Jason Derulo
#
# Song: Watch Where You're Going
# Artist: TNMK
#
# Song: Hto, Yak Ne Ty?
# Artist: Khrystyna Soloviy
#
# Song: Viburnum Cried
# Artist: Polina Dashkova
#
# Song: Heart Of Steel
# Artist: Tvorchi
#
# Song: Good morning, Ukraine
# Artist: Numer 482
#
# Song: Leave Before You Love Me
# Artist: Marshmello & Jonas Brothers
#
# Song: Dolphins
# Artist: M‘yata & Has
#
# Song: Where Did You Go?
# Artist: Jax Jones feat. MNEK
#
# Song: Unknown Hero
# Artist: Ptashkin
#
# Song: Abcdefu
# Artist: Gayle
#
# Song: Saint Javelin
# Artist: TaRuta
#
# Song: A Million On My Soul
# Artist: Alexiane
#
# Song: TDME
# Artist: Antytila
#
# Song: My Way
# Artist: Cassette
#
# Song: It Don't Matter
# Artist: Alok feat. Sofi Tukker & Inna
#
# <Response [200]>
# Song: Flowers
# Artist: Miley Cyrus
#
# Song: Hear The Anthem
# Artist: Skofka
#
# Song: There By The Poplar Tree
# Artist: Artem Pivovarov & NK
#
# Song: Whatever Happens
# Artist: Dorofeeva
#
# Song: That's Good
# Artist: Cheev
#
# Song: Stefania
# Artist: Kalush Orchestra
#
# Song: Near The Heart
# Artist: Kola
#
# Song: Go Home
# Artist: Wellboy
#
# Song: Motherland
# Artist: Kalush & Skofka
#
# Song: Conducted An Excursion
# Artist: Parfeniuk
#
# Song: For The Money Yes
# Artist: Instasamka
#
# Song: Swallows
# Artist: Chico & Qatoshi
#
# Song: Near The Poplar
# Artist: Shumei
#
# Song: Thoughts
# Artist: Artem Pivovarov & Dorofeeva
#
# Song: Waiting At Home
# Artist: Yaktak feat. Dovi
#
# Song: Vespers (Good Day Everybody)
# Artist: 100lycya & Skylerr
#
# Song: Monro
# Artist: Slavik Pogosov
#
# Song: What A Cossack You Are
# Artist: Anna Trincher & Positiff
#
# Song: Shot A Friend
# Artist: Holy Molly
#
# Song: Not About Us
# Artist: Alis Shuka
#
# Song: Middle Of The Night
# Artist: Elley Duhe
#
# Song: Wont Forget You
# Artist: Shouse
#
# Song: How Long
# Artist: Tove Lo
#
# Song: Manifesto (Radio Edit)
# Artist: Artem Pivovarov
#
# Song: You'll Be Happy (Grove, Green Grove)
# Artist: Dima Prokopov
#
# Song: Bunny
# Artist: Anna Trincher
#
# Song: Good Afternoon Everybody
# Artist: Myusli UA feat. Vasia Charizma
#
# Song: Oh, On The Mountain
# Artist: Artem Pivovarov
#
# Song: I'm Good (Blue)
# Artist: David Guetta & Bebe Rexha
#
# Song: Wild Field
# Artist: Yarmak feat. Alisa
#
# Song: My Country
# Artist: Yarmak feat. Tof
#
# Song: In The Dark
# Artist: Purple Disco Machine & Sophie And The Giants
#
# Song: Unbreakable
# Artist: Lyusya Kava
#
# Song: Vanka Standing Up
# Artist: Masha Kondratenko
#
# Song: Ukraine Will Win
# Artist: Oleksandr Ponomaryov & Mykhaylo Khoma & Taras Topolia & Yevhen Koshovyi & Yuriy Tkach & Petro Chornyy
#
# Song: Enemy (Radio Edit)
# Artist: Angy Kreyda
#
# Song: In The Shadows Of Ukraine
# Artist: Kalush Orchestra feat. The Rasmus
#
# Song: Enemy
# Artist: Angy Kreyda
#
# Song: Where
# Artist: Ivan Navi
#
# Song: Sigele-Migele
# Artist: Nazva
#
# Song: View
# Artist: Yaktak feat. Sobol'
#
# Song: We'll Not Forget And We'll Not Forgive
# Artist: Skofka
#
# Song: Oh, Red Viburnum In The Meadow (Army Remix)
# Artist: The Kiffness feat. Boomboks
#
# Song: Crystal
# Artist: NK
#
# Song: As It Was
# Artist: Harry Styles
#
# Song: Mmm
# Artist: Minelli
#
# Song: Dog Patron
# Artist: Karta Svitu
#
# Song: Walking
# Artist: Kozak Siromaha
#
# Song: The AFU Will Help
# Artist: Chico & Qatoshi
#
# Song: At The Bars
# Artist: Anna Asti
#
# Song: Unholy
# Artist: Sam Smith feat. Kim Petras
#
# Song: Marichka
# Artist: Patsyki Z Franeka
#
# Song: Bakhmut
# Artist: Spiv Brativ
#
# Song: Warriors Of Light
# Artist: Lyapis Trubetskoy
#
# Song: This Dream
# Artist: Lesya Nikityuk & Stepan Hiha
#
# Song: Good Evening (Where Are You From?)
# Artist: Probass ∆ Hardi
#
# Song: You Dream
# Artist: Cheev
#
# Song: Bloody Mary
# Artist: Lady Gaga
#
# Song: Live
# Artist: Yuliya Roznen
#
# Song: My Ukraine
# Artist: TamerlanAlena & Andi Vax
#
# Song: My Country
# Artist: Arsen Mirzoyan
#
# Song: Infinity
# Artist: Jaymes Young
#
# Song: Flowers Of Mine Zones
# Artist: Okean El`zy
#
# Song: Silhouettes
# Artist: SadSvit & Struktura Shastya
#
# Song: To The Occupier
# Artist: MBreeze
#
# Song: Counteroffensive
# Artist: Shyman
#
# Song: I'm Writing You A Letter
# Artist: Ivan Navi
#
# Song: You're So Beautiful
# Artist: Quest Pistols
#
# Song: Yin Yan (OST Neighbor)
# Artist: Monatik & Roxolana
#
# Song: Black & White
# Artist: Zozulya
#
# Song: How Mommy
# Artist: Instasamka
#
# Song: Cold Heart (Pnau Remix)
# Artist: Elton John & Dua Lipa & Pnau
#
# Song: Saint Javelin
# Artist: TaRuta
#
# Song: The Motto
# Artist: Tiesto & Ava Max
#
# Song: In Peaceful Kyiv
# Artist: Iksiy & Sestra & BiTZ
#
# Song: Our Father Bandera
# Artist: Glova & Manin & Govorun
#
# Song: Where Did You Go?
# Artist: Jax Jones feat. MNEK
#
# Song: Heart Of Steel
# Artist: Tvorchi
#
# Song: Ukraine Above The Use
# Artist: Myusli UA
#
# Song: How Are You, Kherson?
# Artist: Spiv Brativ
#
# Song: Viburnum Cried
# Artist: Polina Dashkova
#
# Song: On The Road
# Artist: Skofka
#
# Song: Thought She Was An Angel
# Artist: Kolin
#
# Song: I'm A Soldier (2022 UA Version)
# Artist: Serhii Babkin
#
# Song: Unknown Hero
# Artist: Ptashkin
#
# Song: Rampampam
# Artist: Minelli
#
# Song: Tape After Tape
# Artist: Has
#
# Song: People Are Like Ships
# Artist: Antytila
#
# Song: Cossack Genus
# Artist: Jerry Heil
#
# Song: Beat The Muscovite
# Artist: Fiїnka
#
# Song: Take You Dancing
# Artist: Jason Derulo
#
# Song: TDME
# Artist: Antytila
#
# Song: Stork
# Artist: MamaRika feat. Yaktak
#
# Song: Style
# Artist: Wellboy
#
# Song: You're Incredible
# Artist: Quest Pistols
#
# Song: Good morning, Ukraine
# Artist: Numer 482
#
# Song: My Little Hooligan
# Artist: Xolidayboy
#
# Song: Come On, Cossacks
# Artist: Kalush Orchestra & Kozak Siromaha
#
# Song: Another Love
# Artist: Enleo
#
# Song: Don't Be Shy
# Artist: Tiesto & Karol G
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 32
#      30 for week in weeks:
#      31     scrapeData(week)
# ---> 32     time.sleep(5)
#
# KeyboardInterrupt:

# %%
 # Making a GET request
r = requests.get('https://tophit.com/chart/top/media/hits/ukraine/weekly/2023-09-15')
 
# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')

# Locate the element containing the song rows
song_rows = soup.find_all('div', class_='Row_name__vEYs2')

# Extract and print the song data
for song in song_rows:
    song_name = song.find('div', class_='flex items-center gap-x-1.5').text.strip()
    artist_name = song.find('div', class_='truncate pb-0.5 text-sm leading-4 text-gray-500').text.strip()
    
    print(f"Song: {song_name}\nArtist: {artist_name}\n")
# Out:
# Song: At Night
# Artist: Yaktak
#
# Song: If Not For You
# Artist: Maksym Borodin
#
# Song: Currant
# Artist: Yaktak & Kola
#
# Song: By The Storms
# Artist: Shumei & Zlata Ognevich
#
# Song: Smoke
# Artist: Bez obmezhen'
#
# Song: Hey
# Artist: Volodymyr Dantes
#
# Song: Bad Neighbors
# Artist: Skofka
#
# Song: View
# Artist: Yaktak feat. Sobol'
#
# Song: Eyes
# Artist: Artem Pivovarov & Quest Pistols
#
# Song: Waiting At Home
# Artist: Yaktak feat. Dovi
#
# Song: I Love You, But Not Quite
# Artist: Dorofeeva
#
# Song: Fortress Bakhmut
# Artist: Antytila
#
# Song: Above The Clouds
# Artist: Shumei
#
# Song: Manifesto (Radio Edit)
# Artist: Artem Pivovarov
#
# Song: Go Home
# Artist: Wellboy
#
# Song: Paint The Town Red
# Artist: Doja Cat
#
# Song: Flashes
# Artist: Positiff
#
# Song: Doberman
# Artist: Zippo & Agape & Runa
#
# Song: Starfall
# Artist: Max Barskih
#
# Song: Tattoo
# Artist: Loreen
#
# Song: Island
# Artist: Miley Cyrus
#
# Song: People
# Artist: MamaRika & Kola
#
# Song: There By The Poplar Tree
# Artist: Artem Pivovarov & NK
#
# Song: When We're Together
# Artist: Okean El`zy & Kola
#
# Song: Creepin’
# Artist: Metro Boomin & The Weeknd & 21 Savage
#
# Song: You'll Be Happy (Grove, Green Grove)
# Artist: Dima Prokopov
#
# Song: Hero
# Artist: Martin Garrix & Jvke
#
# Song: Rhythms
# Artist: Max Barskih & Dorofeeva
#
# Song: Sparkles
# Artist: 5utra
#
# Song: The Lost Soul Down
# Artist: NBSPLV
#
# Song: Night
# Artist: Oks
#
# Song: Baby Don't Hurt Me
# Artist: David Guetta feat. Anne-Marie & Coi Leray
#
# Song: Puzzle
# Artist: Cheev
#
# Song: Lay Low
# Artist: Tiesto
#
# Song: Habit
# Artist: Grosu
#
# Song: Slowly
# Artist: Adam
#
# Song: The Queen
# Artist: Anna Asti
#
# Song: Whatever Happens
# Artist: Dorofeeva
#
# Song: Motherland
# Artist: Kalush & Skofka
#
# Song: Say Say Say
# Artist: Kygo feat. Paul McCartney & Michael Jackson
#
# Song: When Love Sucks
# Artist: Jason Derulo feat. Dido
#
# Song: Eyes
# Artist: Anna Trincher
#
# Song: Black Russia
# Artist: Morgenshtern
#
# Song: Where My Love Lives
# Artist: Cheev
#
# Song: The Sky Is Leaning
# Artist: alyona alyona & Kola
#
# Song: Starlight
# Artist: Drenchill feat. Jorik Burema
#
# Song: I'm Crying
# Artist: A.V.G
#
# Song: Belgorod (Cultural Landing)
# Artist: Sasha Chemerov & Misha Krupin & Kolya Sierga
#
# Song: You Dream
# Artist: Cheev
#
# Song: Forget Me
# Artist: Lewis Capaldi
#
# Song: Sekret (Radio edit)
# Artist: Druha Rika
#
# Song: Don't Be Silent
# Artist: Yaktak
#
# Song: Mania
# Artist: Xolidayboy
#
# Song: Strangers
# Artist: Kenya Grace
#
# Song: In The Dark
# Artist: Purple Disco Machine & Sophie And The Giants
#
# Song: Flowers
# Artist: Miley Cyrus
#
# Song: The Last Days Of Summer
# Artist: Spiv Brativ
#
# Song: Bakhmut
# Artist: Spiv Brativ
#
# Song: Makeba
# Artist: Jain
#
# Song: A Soldier's Prayer
# Artist: Burla
#
# Song: For A Moment
# Artist: Ivan Navi
#
# Song: Stork
# Artist: MamaRika feat. Yaktak
#
# Song: The AFU Will Help
# Artist: Chico & Qatoshi
#
# Song: Hear The Anthem
# Artist: Skofka
#
# Song: Infinity
# Artist: Jaymes Young
#
# Song: 1.Kla$
# Artist: Oxxxymiron
#
# Song: I'm Good (Blue)
# Artist: David Guetta & Bebe Rexha
#
# Song: 11/11
# Artist: Arsen Mirzoyan
#
# Song: Palms
# Artist: Parfeniuk
#
# Song: Gaddemit
# Artist: Gezweirdo
#
# Song: Dzheral'dina
# Artist: Arsen Mirzoyan
#
# Song: Not About Us
# Artist: Alis Shuka
#
# Song: Heavy Metal Love
# Artist: Twocolors
#
# Song: Wont Forget You
# Artist: Shouse
#
# Song: Madame
# Artist: 100lycya
#
# Song: Roses
# Artist: 100lycya
#
# Song: Love Tonight
# Artist: Shouse
#
# Song: China
# Artist: Irina Kairatovna
#
# Song: You Can't Do Without It
# Artist: Bez obmezhen'
#
# Song: That's Good
# Artist: Cheev
#
# Song: (It Goes Like) Nanana
# Artist: Peggy Gou
#
# Song: Vespers (Good Day Everybody)
# Artist: 100lycya & Skylerr
#
# Song: Dym
# Artist: Vremya i Steklo
#
# Song: In The Garden
# Artist: Artison
#
# Song: Bones
# Artist: Imagine Dragons
#
# Song: Katsaps (Radio Edit)
# Artist: Tik
#
# Song: Cold Heart (Pnau Remix)
# Artist: Elton John & Dua Lipa & Pnau
#
# Song: Flash
# Artist: Taras Keen
#
# Song: Your Love (9pm)
# Artist: ATB & Topic & A7S
#
# Song: Heart Of Steel
# Artist: Tvorchi
#
# Song: Going Home
# Artist: Kalush feat. Skofka
#
# Song: Starfalls
# Artist: Kola & Adam
#
# Song: Believer
# Artist: Imagine Dragons
#
# Song: Diamonds
# Artist: Rihanna
#
# Song: In the Fall of Leaves
# Artist: Gio Pika
#
# Song: Your Tattoos
# Artist: Ostrovskyi & Mayorova
#
# Song: Queencard (퀸카)
# Artist: (G)I-DLE
#
# Song: My Way
# Artist: Cassette
#
# Song: Ragnarok
# Artist: Yarmak
#
# Song: Seven
# Artist: Jung Kook feat. Latto
